# %%
import np as np

import Ramsey_ExperimentV3
from tqdm import tqdm
import random

import estimator
import numpy as np

# %%
fitted_data = []
T = 1 * np.pi
uni_delay = np.linspace(0, T, 20)
shots = 5000

n = 1
delay = [1]
fisher_delay = [0.4439410861020235, 1.784695781691183]

decay_fit = []

repetitions = 1000
# W =]
Decay = np.arange(0.001, 3.1, 0.25)
# np.delete(W, 0)
W = [1]
J = {}
J_list = [random.gauss(1, 0) for _ in range(n - 1)]
for rep in tqdm(range(repetitions), desc="Repetition"):
    rep_decay_fit = []
    for decay in Decay:
        # Create experiments
        batch_x_det, batch_y_det, batch_x_cross, batch_y_cross = Ramsey_ExperimentV3.ramsey_local(
            n, shots, delay, [decay], W, J
        )
        batch_det, batch_cross = Ramsey_ExperimentV3.ramsey_local_X(n, shots, fisher_delay, [decay], W, J)
        batch_det_uni_x, batch_cross_uni_x = Ramsey_ExperimentV3.ramsey_local_X(n, shots, uni_delay, [decay], W, J)

        batch_x_det_uni, batch_y_det_uni, batch_x_cross_uni, batch_y_cross_uni = Ramsey_ExperimentV3.ramsey_local(
            n, shots, uni_delay, [decay], W, J
        )

        # Append batches and decay to decay fit list
        rep_decay_fit.append((
            decay,
            (batch_x_det, batch_y_det, batch_x_cross, batch_y_cross),
            (batch_det, batch_cross),
            (batch_x_det_uni, batch_y_det_uni, batch_x_cross_uni, batch_y_cross_uni),
            (batch_det_uni_x, batch_cross_uni_x)
        ))

    decay_fit.append(rep_decay_fit)
# Out:
# Repetition:   0%|          | 0/1000 [01:17<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      23 batch_x_det, batch_y_det, batch_x_cross, batch_y_cross = Ramsey_ExperimentV3.ramsey_local(
#      24     n, shots, delay, [decay], W, J
#      25 )
#      26 batch_det, batch_cross = Ramsey_ExperimentV3.ramsey_local_X(n, shots, fisher_delay, [decay], W, J)
# ---> 27 batch_det_uni_x, batch_cross_uni_x = Ramsey_ExperimentV3.ramsey_local_X(n, shots, uni_delay, [decay], W, J)
#      29 batch_x_det_uni, batch_y_det_uni, batch_x_cross_uni, batch_y_cross_uni = Ramsey_ExperimentV3.ramsey_local(
#      30     n, shots, uni_delay, [decay], W, J
#      31 )
#      33 # Append batches and decay to decay fit list
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1187, in _pydevd_bundle.pydevd_cython_win32_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:937, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:928, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:585, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.do_wait_suspend()
#
# File C:\Program Files\JetBrains\PyCharm 2024.3\plugins\python-ce\helpers\pydev\pydevd.py:1220, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1217         from_this_thread.append(frame_id)
#    1219 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1220     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2024.3\plugins\python-ce\helpers\pydev\pydevd.py:1235, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1232             self._call_mpl_hook()
#    1234         self.process_internal_commands()
# -> 1235         time.sleep(0.01)
#    1237 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1239 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
from importlib import reload
reload(estimator)
# Out:
# <module 'estimator' from 'C:\\Projects\\Crosstalk\\estimator.py'>

# %%
# #load from pickle
# with open('decay_fit.pkl', 'rb') as f:
#     decay_fit = pkl.load(f)
for rep, rep_batches in enumerate(decay_fit):
    rep_fits = []
    print(f"Repetition {rep} / {repetitions}")
    for decay, (batch_x_det, batch_y_det, batch_x_cross, batch_y_cross), (batch_det, batch_cross), (batch_x_det_uni, batch_y_det_uni, batch_x_cross_uni, batch_y_cross_uni),(batch_det_uni_x, batch_cross_uni_x)  in rep_batches:
        Decay_local, W_local, J_local = estimator.one_by_one_fit(batch_x_det, batch_y_det, batch_x_cross, batch_y_cross)
        Decay_fisher, W_fisher, J_fisher = estimator.one_by_one_X(batch_det, batch_cross)
        Decay_uni, W_uni, J_uni = estimator.one_by_one_fit(batch_x_det_uni, batch_y_det_uni, batch_x_cross_uni, batch_y_cross_uni)
        Decay_uni_X, W_uni_X, J_uni_X = estimator.one_by_one_X(batch_det_uni_x, batch_cross_uni_x)

        rep_fits.append((
            decay,
            (Decay_local, W_local, J_local),
            (Decay_fisher, W_fisher, J_fisher),
            (Decay_uni, W_uni, J_uni),
            (Decay_uni_X, W_uni_X, J_uni_X)
        ))

    fitted_data.append(rep_fits)
# Out:
# Repetition 0 / 1000
# Repetition 1 / 1000
# C:\Projects\Crosstalk\estimator.py:36: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, params_covariance, *c = curve_fit(model_func, t_points, z_points, p0=initial_guess, bounds=bounds)
# C:\Projects\Crosstalk\estimator.py:66: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, params_covariance, *c = curve_fit(model_func, t_points, z_points, p0=initial_guess, bounds=bounds)
# Repetition 2 / 1000
# Repetition 3 / 1000
# Repetition 4 / 1000
# Repetition 5 / 1000
# Repetition 6 / 1000
# Repetition 7 / 1000
# Repetition 8 / 1000
# Repetition 9 / 1000
# Repetition 10 / 1000
# Repetition 11 / 1000
# Repetition 12 / 1000
# Repetition 13 / 1000
# Repetition 14 / 1000
# Repetition 15 / 1000
# Repetition 16 / 1000
# Repetition 17 / 1000
# Repetition 18 / 1000
# Repetition 19 / 1000
# Repetition 20 / 1000
# Repetition 21 / 1000
# Repetition 22 / 1000
# Repetition 23 / 1000
# Repetition 24 / 1000
# Repetition 25 / 1000
# Repetition 26 / 1000
# Repetition 27 / 1000
# Repetition 28 / 1000
# Repetition 29 / 1000
# Repetition 30 / 1000
# Repetition 31 / 1000
# Repetition 32 / 1000
# Repetition 33 / 1000
# Repetition 34 / 1000
# Repetition 35 / 1000
# Repetition 36 / 1000
# Repetition 37 / 1000
# Repetition 38 / 1000
# Repetition 39 / 1000
# Repetition 40 / 1000
# Repetition 41 / 1000
# Repetition 42 / 1000
# Repetition 43 / 1000
# Repetition 44 / 1000
# Repetition 45 / 1000
# Repetition 46 / 1000
# Repetition 47 / 1000
# Repetition 48 / 1000
# Repetition 49 / 1000
# Repetition 50 / 1000
# Repetition 51 / 1000
# Repetition 52 / 1000
# Repetition 53 / 1000
# Repetition 54 / 1000
# Repetition 55 / 1000
# Repetition 56 / 1000
# Repetition 57 / 1000
# Repetition 58 / 1000
# Repetition 59 / 1000
# Repetition 60 / 1000
# Repetition 61 / 1000
# Repetition 62 / 1000
# Repetition 63 / 1000
# Repetition 64 / 1000
# Repetition 65 / 1000
# Repetition 66 / 1000
# Repetition 67 / 1000
# Repetition 68 / 1000
# Repetition 69 / 1000
# Repetition 70 / 1000
# Repetition 71 / 1000
# Repetition 72 / 1000
# Repetition 73 / 1000
# Repetition 74 / 1000
# Repetition 75 / 1000
# Repetition 76 / 1000
# Repetition 77 / 1000
# Repetition 78 / 1000
# Repetition 79 / 1000
# Repetition 80 / 1000
# Repetition 81 / 1000
# Repetition 82 / 1000
# Repetition 83 / 1000
# Repetition 84 / 1000
# Repetition 85 / 1000
# Repetition 86 / 1000
# Repetition 87 / 1000
# Repetition 88 / 1000
# Repetition 89 / 1000
# Repetition 90 / 1000
# Repetition 91 / 1000
# Repetition 92 / 1000
# Repetition 93 / 1000
# Repetition 94 / 1000
# Repetition 95 / 1000
# Repetition 96 / 1000
# Repetition 97 / 1000
# Repetition 98 / 1000
# Repetition 99 / 1000
# Repetition 100 / 1000
# Repetition 101 / 1000
# Repetition 102 / 1000
# Repetition 103 / 1000
# Repetition 104 / 1000
# Repetition 105 / 1000
# Repetition 106 / 1000
# Repetition 107 / 1000
# Repetition 108 / 1000
# Repetition 109 / 1000
# Repetition 110 / 1000
# Repetition 111 / 1000
# Repetition 112 / 1000
# Repetition 113 / 1000
# Repetition 114 / 1000
# Repetition 115 / 1000
# Repetition 116 / 1000
# Repetition 117 / 1000
# Repetition 118 / 1000
# Repetition 119 / 1000
# Repetition 120 / 1000
# Repetition 121 / 1000
# Repetition 122 / 1000
# Repetition 123 / 1000
# Repetition 124 / 1000
# Repetition 125 / 1000
# Repetition 126 / 1000
# Repetition 127 / 1000
# Repetition 128 / 1000
# Repetition 129 / 1000
# Repetition 130 / 1000
# Repetition 131 / 1000
# Repetition 132 / 1000
# Repetition 133 / 1000
# Repetition 134 / 1000
# Repetition 135 / 1000
# Repetition 136 / 1000
# Repetition 137 / 1000
# Repetition 138 / 1000
# Repetition 139 / 1000
# Repetition 140 / 1000
# Repetition 141 / 1000
# Repetition 142 / 1000
# Repetition 143 / 1000
# Repetition 144 / 1000
# Repetition 145 / 1000
# Repetition 146 / 1000
# Repetition 147 / 1000
# Repetition 148 / 1000
# Repetition 149 / 1000
# Repetition 150 / 1000
# Repetition 151 / 1000
# Repetition 152 / 1000
# Repetition 153 / 1000
# Repetition 154 / 1000
# Repetition 155 / 1000
# Repetition 156 / 1000
# Repetition 157 / 1000
# Repetition 158 / 1000
# Repetition 159 / 1000
# Repetition 160 / 1000
# Repetition 161 / 1000
# Repetition 162 / 1000
# Repetition 163 / 1000
# Repetition 164 / 1000
# Repetition 165 / 1000
# Repetition 166 / 1000
# Repetition 167 / 1000
# Repetition 168 / 1000
# Repetition 169 / 1000
# Repetition 170 / 1000
# Repetition 171 / 1000
# Repetition 172 / 1000
# Repetition 173 / 1000
# Repetition 174 / 1000
# Repetition 175 / 1000
# Repetition 176 / 1000
# Repetition 177 / 1000
# Repetition 178 / 1000
# Repetition 179 / 1000
# Repetition 180 / 1000
# Repetition 181 / 1000
# Repetition 182 / 1000
# Repetition 183 / 1000
# Repetition 184 / 1000
# Repetition 185 / 1000
# Repetition 186 / 1000
# Repetition 187 / 1000
# Repetition 188 / 1000
# Repetition 189 / 1000
# Repetition 190 / 1000
# Repetition 191 / 1000
# Repetition 192 / 1000
# Repetition 193 / 1000
# Repetition 194 / 1000
# Repetition 195 / 1000
# Repetition 196 / 1000
# Repetition 197 / 1000
# Repetition 198 / 1000
# Repetition 199 / 1000
# Repetition 200 / 1000
# Repetition 201 / 1000
# Repetition 202 / 1000
# Repetition 203 / 1000
# Repetition 204 / 1000
# Repetition 205 / 1000
# Repetition 206 / 1000
# Repetition 207 / 1000
# Repetition 208 / 1000
# Repetition 209 / 1000
# Repetition 210 / 1000
# Repetition 211 / 1000
# Repetition 212 / 1000
# Repetition 213 / 1000
# Repetition 214 / 1000
# Repetition 215 / 1000
# Repetition 216 / 1000
# Repetition 217 / 1000
# Repetition 218 / 1000
# Repetition 219 / 1000
# Repetition 220 / 1000
# Repetition 221 / 1000
# Repetition 222 / 1000
# Repetition 223 / 1000
# Repetition 224 / 1000
# Repetition 225 / 1000
# Repetition 226 / 1000
# Repetition 227 / 1000
# Repetition 228 / 1000
# Repetition 229 / 1000
# Repetition 230 / 1000
# Repetition 231 / 1000
# Repetition 232 / 1000
# Repetition 233 / 1000
# Repetition 234 / 1000
# Repetition 235 / 1000
# Repetition 236 / 1000
# Repetition 237 / 1000
# Repetition 238 / 1000
# Repetition 239 / 1000
# Repetition 240 / 1000
# Repetition 241 / 1000
# Repetition 242 / 1000
# Repetition 243 / 1000
# Repetition 244 / 1000
# Repetition 245 / 1000
# Repetition 246 / 1000
# Repetition 247 / 1000
# Repetition 248 / 1000
# Repetition 249 / 1000
# Repetition 250 / 1000
# Repetition 251 / 1000
# Repetition 252 / 1000
# Repetition 253 / 1000
# Repetition 254 / 1000
# Repetition 255 / 1000
# Repetition 256 / 1000
# Repetition 257 / 1000
# Repetition 258 / 1000
# Repetition 259 / 1000
# Repetition 260 / 1000
# Repetition 261 / 1000
# Repetition 262 / 1000
# Repetition 263 / 1000
# Repetition 264 / 1000
# Repetition 265 / 1000
# Repetition 266 / 1000
# Repetition 267 / 1000
# Repetition 268 / 1000
# Repetition 269 / 1000
# Repetition 270 / 1000
# Repetition 271 / 1000
# Repetition 272 / 1000
# Repetition 273 / 1000
# Repetition 274 / 1000
# Repetition 275 / 1000
# Repetition 276 / 1000
# Repetition 277 / 1000
# Repetition 278 / 1000
# Repetition 279 / 1000
# Repetition 280 / 1000
# Repetition 281 / 1000
# Repetition 282 / 1000
# Repetition 283 / 1000
# Repetition 284 / 1000
# Repetition 285 / 1000
# Repetition 286 / 1000
# Repetition 287 / 1000
# Repetition 288 / 1000
# Repetition 289 / 1000
# Repetition 290 / 1000
# Repetition 291 / 1000
# Repetition 292 / 1000
# Repetition 293 / 1000
# Repetition 294 / 1000
# Repetition 295 / 1000
# Repetition 296 / 1000
# Repetition 297 / 1000
# Repetition 298 / 1000
# Repetition 299 / 1000
# Repetition 300 / 1000
# Repetition 301 / 1000
# Repetition 302 / 1000
# Repetition 303 / 1000
# Repetition 304 / 1000
# Repetition 305 / 1000
# Repetition 306 / 1000
# Repetition 307 / 1000
# Repetition 308 / 1000
# Repetition 309 / 1000
# Repetition 310 / 1000
# Repetition 311 / 1000
# Repetition 312 / 1000
# Repetition 313 / 1000
# Repetition 314 / 1000
# Repetition 315 / 1000
# Repetition 316 / 1000
# Repetition 317 / 1000
# Repetition 318 / 1000
# Repetition 319 / 1000
# Repetition 320 / 1000
# Repetition 321 / 1000
# Repetition 322 / 1000
# Repetition 323 / 1000
# Repetition 324 / 1000
# Repetition 325 / 1000
# Repetition 326 / 1000
# Repetition 327 / 1000
# Repetition 328 / 1000
# Repetition 329 / 1000
# Repetition 330 / 1000
# Repetition 331 / 1000
# Repetition 332 / 1000
# Repetition 333 / 1000
# Repetition 334 / 1000
# Repetition 335 / 1000
# Repetition 336 / 1000
# Repetition 337 / 1000
# Repetition 338 / 1000
# Repetition 339 / 1000
# Repetition 340 / 1000
# Repetition 341 / 1000
# Repetition 342 / 1000
# Repetition 343 / 1000
# Repetition 344 / 1000
# Repetition 345 / 1000
# Repetition 346 / 1000
# Repetition 347 / 1000
# Repetition 348 / 1000
# Repetition 349 / 1000
# Repetition 350 / 1000
# Repetition 351 / 1000
# Repetition 352 / 1000
# Repetition 353 / 1000
# Repetition 354 / 1000
# Repetition 355 / 1000
# Repetition 356 / 1000
# Repetition 357 / 1000
# Repetition 358 / 1000
# Repetition 359 / 1000
# Repetition 360 / 1000
# Repetition 361 / 1000
# Repetition 362 / 1000
# Repetition 363 / 1000
# Repetition 364 / 1000
# Repetition 365 / 1000
# Repetition 366 / 1000
# Repetition 367 / 1000
# Repetition 368 / 1000
# Repetition 369 / 1000
# Repetition 370 / 1000
# Repetition 371 / 1000
# Repetition 372 / 1000
# Repetition 373 / 1000
# Repetition 374 / 1000
# Repetition 375 / 1000
# Repetition 376 / 1000
# Repetition 377 / 1000
# Repetition 378 / 1000
# Repetition 379 / 1000
# Repetition 380 / 1000
# Repetition 381 / 1000
# Repetition 382 / 1000
# Repetition 383 / 1000
# Repetition 384 / 1000
# Repetition 385 / 1000
# Repetition 386 / 1000
# Repetition 387 / 1000
# Repetition 388 / 1000
# Repetition 389 / 1000
# Repetition 390 / 1000
# Repetition 391 / 1000
# Repetition 392 / 1000
# Repetition 393 / 1000
# Repetition 394 / 1000
# Repetition 395 / 1000
# Repetition 396 / 1000
# Repetition 397 / 1000
# Repetition 398 / 1000
# Repetition 399 / 1000
# Repetition 400 / 1000
# Repetition 401 / 1000
# Repetition 402 / 1000
# Repetition 403 / 1000
# Repetition 404 / 1000
# Repetition 405 / 1000
# Repetition 406 / 1000
# Repetition 407 / 1000
# Repetition 408 / 1000
# Repetition 409 / 1000
# Repetition 410 / 1000
# Repetition 411 / 1000
# Repetition 412 / 1000
# Repetition 413 / 1000
# Repetition 414 / 1000
# Repetition 415 / 1000
# Repetition 416 / 1000
# Repetition 417 / 1000
# Repetition 418 / 1000
# Repetition 419 / 1000
# Repetition 420 / 1000
# Repetition 421 / 1000
# Repetition 422 / 1000
# Repetition 423 / 1000
# Repetition 424 / 1000
# Repetition 425 / 1000
# Repetition 426 / 1000
# Repetition 427 / 1000
# Repetition 428 / 1000
# Repetition 429 / 1000
# Repetition 430 / 1000
# Repetition 431 / 1000
# Repetition 432 / 1000
# Repetition 433 / 1000
# Repetition 434 / 1000
# Repetition 435 / 1000
# Repetition 436 / 1000
# Repetition 437 / 1000
# Repetition 438 / 1000
# Repetition 439 / 1000
# Repetition 440 / 1000
# Repetition 441 / 1000
# Repetition 442 / 1000
# Repetition 443 / 1000
# Repetition 444 / 1000
# Repetition 445 / 1000
# Repetition 446 / 1000
# Repetition 447 / 1000
# Repetition 448 / 1000
# Repetition 449 / 1000
# Repetition 450 / 1000
# Repetition 451 / 1000
# Repetition 452 / 1000
# Repetition 453 / 1000
# Repetition 454 / 1000
# Repetition 455 / 1000
# Repetition 456 / 1000
# Repetition 457 / 1000
# Repetition 458 / 1000
# Repetition 459 / 1000
# Repetition 460 / 1000
# Repetition 461 / 1000
# Repetition 462 / 1000
# Repetition 463 / 1000
# Repetition 464 / 1000
# Repetition 465 / 1000
# Repetition 466 / 1000
# Repetition 467 / 1000
# Repetition 468 / 1000
# Repetition 469 / 1000
# Repetition 470 / 1000
# Repetition 471 / 1000
# Repetition 472 / 1000
# Repetition 473 / 1000
# Repetition 474 / 1000
# Repetition 475 / 1000
# Repetition 476 / 1000
# Repetition 477 / 1000
# Repetition 478 / 1000
# Repetition 479 / 1000
# Repetition 480 / 1000
# Repetition 481 / 1000
# Repetition 482 / 1000
# Repetition 483 / 1000
# Repetition 484 / 1000
# Repetition 485 / 1000
# Repetition 486 / 1000
# Repetition 487 / 1000
# Repetition 488 / 1000
# Repetition 489 / 1000
# Repetition 490 / 1000
# Repetition 491 / 1000
# Repetition 492 / 1000
# Repetition 493 / 1000
# Repetition 494 / 1000
# Repetition 495 / 1000
# Repetition 496 / 1000
# Repetition 497 / 1000
# Repetition 498 / 1000
# Repetition 499 / 1000
# Repetition 500 / 1000
# Repetition 501 / 1000
# Repetition 502 / 1000
# Repetition 503 / 1000
# Repetition 504 / 1000
# Repetition 505 / 1000
# Repetition 506 / 1000
# Repetition 507 / 1000
# Repetition 508 / 1000
# Repetition 509 / 1000
# Repetition 510 / 1000
# Repetition 511 / 1000
# Repetition 512 / 1000
# Repetition 513 / 1000
# Repetition 514 / 1000
# Repetition 515 / 1000
# Repetition 516 / 1000
# Repetition 517 / 1000
# Repetition 518 / 1000
# Repetition 519 / 1000
# Repetition 520 / 1000
# Repetition 521 / 1000
# Repetition 522 / 1000
# Repetition 523 / 1000
# Repetition 524 / 1000
# Repetition 525 / 1000
# Repetition 526 / 1000
# Repetition 527 / 1000
# Repetition 528 / 1000
# Repetition 529 / 1000
# Repetition 530 / 1000
# Repetition 531 / 1000
# Repetition 532 / 1000
# Repetition 533 / 1000
# Repetition 534 / 1000
# Repetition 535 / 1000
# Repetition 536 / 1000
# Repetition 537 / 1000
# Repetition 538 / 1000
# Repetition 539 / 1000
# Repetition 540 / 1000
# Repetition 541 / 1000
# Repetition 542 / 1000
# Repetition 543 / 1000
# Repetition 544 / 1000
# Repetition 545 / 1000
# Repetition 546 / 1000
# Repetition 547 / 1000
# Repetition 548 / 1000
# Repetition 549 / 1000
# Repetition 550 / 1000
# Repetition 551 / 1000
# Repetition 552 / 1000
# Repetition 553 / 1000
# Repetition 554 / 1000
# Repetition 555 / 1000
# Repetition 556 / 1000
# Repetition 557 / 1000
# Repetition 558 / 1000
# Repetition 559 / 1000
# Repetition 560 / 1000
# Repetition 561 / 1000
# Repetition 562 / 1000
# Repetition 563 / 1000
# Repetition 564 / 1000
# Repetition 565 / 1000
# Repetition 566 / 1000
# Repetition 567 / 1000
# Repetition 568 / 1000
# Repetition 569 / 1000
# Repetition 570 / 1000
# Repetition 571 / 1000
# Repetition 572 / 1000
# Repetition 573 / 1000
# Repetition 574 / 1000
# Repetition 575 / 1000
# Repetition 576 / 1000
# Repetition 577 / 1000
# Repetition 578 / 1000
# Repetition 579 / 1000
# Repetition 580 / 1000
# Repetition 581 / 1000
# Repetition 582 / 1000
# Repetition 583 / 1000
# Repetition 584 / 1000
# Repetition 585 / 1000
# Repetition 586 / 1000
# Repetition 587 / 1000
# Repetition 588 / 1000
# Repetition 589 / 1000
# Repetition 590 / 1000
# Repetition 591 / 1000
# Repetition 592 / 1000
# Repetition 593 / 1000
# Repetition 594 / 1000
# Repetition 595 / 1000
# Repetition 596 / 1000
# Repetition 597 / 1000
# Repetition 598 / 1000
# Repetition 599 / 1000
# Repetition 600 / 1000
# Repetition 601 / 1000
# Repetition 602 / 1000
# Repetition 603 / 1000
# Repetition 604 / 1000
# Repetition 605 / 1000
# Repetition 606 / 1000
# Repetition 607 / 1000
# Repetition 608 / 1000
# Repetition 609 / 1000
# Repetition 610 / 1000
# Repetition 611 / 1000
# Repetition 612 / 1000
# Repetition 613 / 1000
# Repetition 614 / 1000
# Repetition 615 / 1000
# Repetition 616 / 1000
# Repetition 617 / 1000
# Repetition 618 / 1000
# Repetition 619 / 1000
# Repetition 620 / 1000
# Repetition 621 / 1000
# Repetition 622 / 1000
# Repetition 623 / 1000
# Repetition 624 / 1000
# Repetition 625 / 1000
# Repetition 626 / 1000
# Repetition 627 / 1000
# Repetition 628 / 1000
# Repetition 629 / 1000
# Repetition 630 / 1000
# Repetition 631 / 1000
# Repetition 632 / 1000
# Repetition 633 / 1000
# Repetition 634 / 1000
# Repetition 635 / 1000
# Repetition 636 / 1000
# Repetition 637 / 1000
# Repetition 638 / 1000
# Repetition 639 / 1000
# Repetition 640 / 1000
# Repetition 641 / 1000
# Repetition 642 / 1000
# Repetition 643 / 1000
# Repetition 644 / 1000
# Repetition 645 / 1000
# Repetition 646 / 1000
# Repetition 647 / 1000
# Repetition 648 / 1000
# Repetition 649 / 1000
# Repetition 650 / 1000
# Repetition 651 / 1000
# Repetition 652 / 1000
# Repetition 653 / 1000
# Repetition 654 / 1000
# Repetition 655 / 1000
# Repetition 656 / 1000
# Repetition 657 / 1000
# Repetition 658 / 1000
# Repetition 659 / 1000
# Repetition 660 / 1000
# Repetition 661 / 1000
# Repetition 662 / 1000
# Repetition 663 / 1000
# Repetition 664 / 1000
# Repetition 665 / 1000
# Repetition 666 / 1000
# Repetition 667 / 1000
# Repetition 668 / 1000
# Repetition 669 / 1000
# Repetition 670 / 1000
# Repetition 671 / 1000
# Repetition 672 / 1000
# Repetition 673 / 1000
# Repetition 674 / 1000
# Repetition 675 / 1000
# Repetition 676 / 1000
# Repetition 677 / 1000
# Repetition 678 / 1000
# Repetition 679 / 1000
# Repetition 680 / 1000
# Repetition 681 / 1000
# Repetition 682 / 1000
# Repetition 683 / 1000
# Repetition 684 / 1000
# Repetition 685 / 1000
# Repetition 686 / 1000
# Repetition 687 / 1000
# Repetition 688 / 1000
# Repetition 689 / 1000
# Repetition 690 / 1000
# Repetition 691 / 1000
# Repetition 692 / 1000
# Repetition 693 / 1000
# Repetition 694 / 1000
# Repetition 695 / 1000
# Repetition 696 / 1000
# Repetition 697 / 1000
# Repetition 698 / 1000
# Repetition 699 / 1000
# Repetition 700 / 1000
# Repetition 701 / 1000
# Repetition 702 / 1000
# Repetition 703 / 1000
# Repetition 704 / 1000
# Repetition 705 / 1000
# Repetition 706 / 1000
# Repetition 707 / 1000
# Repetition 708 / 1000
# Repetition 709 / 1000
# Repetition 710 / 1000
# Repetition 711 / 1000
# Repetition 712 / 1000
# Repetition 713 / 1000
# Repetition 714 / 1000
# Repetition 715 / 1000
# Repetition 716 / 1000
# Repetition 717 / 1000
# Repetition 718 / 1000
# Repetition 719 / 1000
# Repetition 720 / 1000
# Repetition 721 / 1000
# Repetition 722 / 1000
# Repetition 723 / 1000
# Repetition 724 / 1000
# Repetition 725 / 1000
# Repetition 726 / 1000
# Repetition 727 / 1000
# Repetition 728 / 1000
# Repetition 729 / 1000
# Repetition 730 / 1000
# Repetition 731 / 1000
# Repetition 732 / 1000
# Repetition 733 / 1000
# Repetition 734 / 1000
# Repetition 735 / 1000
# Repetition 736 / 1000
# Repetition 737 / 1000
# Repetition 738 / 1000
# Repetition 739 / 1000
# Repetition 740 / 1000
# Repetition 741 / 1000
# Repetition 742 / 1000
# Repetition 743 / 1000
# Repetition 744 / 1000
# Repetition 745 / 1000
# Repetition 746 / 1000
# Repetition 747 / 1000
# Repetition 748 / 1000
# Repetition 749 / 1000
# Repetition 750 / 1000
# Repetition 751 / 1000
# Repetition 752 / 1000
# Repetition 753 / 1000
# Repetition 754 / 1000
# Repetition 755 / 1000
# Repetition 756 / 1000
# Repetition 757 / 1000
# Repetition 758 / 1000
# Repetition 759 / 1000
# Repetition 760 / 1000
# Repetition 761 / 1000
# Repetition 762 / 1000
# Repetition 763 / 1000
# Repetition 764 / 1000
# Repetition 765 / 1000
# Repetition 766 / 1000
# Repetition 767 / 1000
# Repetition 768 / 1000
# Repetition 769 / 1000
# Repetition 770 / 1000
# Repetition 771 / 1000
# Repetition 772 / 1000
# Repetition 773 / 1000
# Repetition 774 / 1000
# Repetition 775 / 1000
# Repetition 776 / 1000
# Repetition 777 / 1000
# Repetition 778 / 1000
# Repetition 779 / 1000
# Repetition 780 / 1000
# Repetition 781 / 1000
# Repetition 782 / 1000
# Repetition 783 / 1000
# Repetition 784 / 1000
# Repetition 785 / 1000
# Repetition 786 / 1000
# Repetition 787 / 1000
# Repetition 788 / 1000
# Repetition 789 / 1000
# Repetition 790 / 1000
# Repetition 791 / 1000
# Repetition 792 / 1000
# Repetition 793 / 1000
# Repetition 794 / 1000
# Repetition 795 / 1000
# Repetition 796 / 1000
# Repetition 797 / 1000
# Repetition 798 / 1000
# Repetition 799 / 1000
# Repetition 800 / 1000
# Repetition 801 / 1000
# Repetition 802 / 1000
# Repetition 803 / 1000
# Repetition 804 / 1000
# Repetition 805 / 1000
# Repetition 806 / 1000
# Repetition 807 / 1000
# Repetition 808 / 1000
# Repetition 809 / 1000
# Repetition 810 / 1000
# Repetition 811 / 1000
# Repetition 812 / 1000
# Repetition 813 / 1000
# Repetition 814 / 1000
# Repetition 815 / 1000
# Repetition 816 / 1000
# Repetition 817 / 1000
# Repetition 818 / 1000
# Repetition 819 / 1000
# Repetition 820 / 1000
# Repetition 821 / 1000
# Repetition 822 / 1000
# Repetition 823 / 1000
# Repetition 824 / 1000
# Repetition 825 / 1000
# Repetition 826 / 1000
# Repetition 827 / 1000
# Repetition 828 / 1000
# Repetition 829 / 1000
# Repetition 830 / 1000
# Repetition 831 / 1000
# Repetition 832 / 1000
# Repetition 833 / 1000
# Repetition 834 / 1000
# Repetition 835 / 1000
# Repetition 836 / 1000
# Repetition 837 / 1000
# Repetition 838 / 1000
# Repetition 839 / 1000
# Repetition 840 / 1000
# Repetition 841 / 1000
# Repetition 842 / 1000
# Repetition 843 / 1000
# Repetition 844 / 1000
# Repetition 845 / 1000
# Repetition 846 / 1000
# Repetition 847 / 1000
# Repetition 848 / 1000
# Repetition 849 / 1000
# Repetition 850 / 1000
# Repetition 851 / 1000
# Repetition 852 / 1000
# Repetition 853 / 1000
# Repetition 854 / 1000
# Repetition 855 / 1000
# Repetition 856 / 1000
# Repetition 857 / 1000
# Repetition 858 / 1000
# Repetition 859 / 1000
# Repetition 860 / 1000
# Repetition 861 / 1000
# Repetition 862 / 1000
# Repetition 863 / 1000
# Repetition 864 / 1000
# Repetition 865 / 1000
# Repetition 866 / 1000
# Repetition 867 / 1000
# Repetition 868 / 1000
# Repetition 869 / 1000
# Repetition 870 / 1000
# Repetition 871 / 1000
# Repetition 872 / 1000
# Repetition 873 / 1000
# Repetition 874 / 1000
# Repetition 875 / 1000
# Repetition 876 / 1000
# Repetition 877 / 1000
# Repetition 878 / 1000
# Repetition 879 / 1000
# Repetition 880 / 1000
# Repetition 881 / 1000
# Repetition 882 / 1000
# Repetition 883 / 1000
# Repetition 884 / 1000
# Repetition 885 / 1000
# Repetition 886 / 1000
# Repetition 887 / 1000
# Repetition 888 / 1000
# Repetition 889 / 1000
# Repetition 890 / 1000
# Repetition 891 / 1000
# Repetition 892 / 1000
# Repetition 893 / 1000
# Repetition 894 / 1000
# Repetition 895 / 1000
# Repetition 896 / 1000
# Repetition 897 / 1000
# Repetition 898 / 1000
# Repetition 899 / 1000
# Repetition 900 / 1000
# Repetition 901 / 1000
# Repetition 902 / 1000
# Repetition 903 / 1000
# Repetition 904 / 1000
# Repetition 905 / 1000
# Repetition 906 / 1000
# Repetition 907 / 1000
# Repetition 908 / 1000
# Repetition 909 / 1000
# Repetition 910 / 1000
# Repetition 911 / 1000
# Repetition 912 / 1000
# Repetition 913 / 1000
# Repetition 914 / 1000
# Repetition 915 / 1000
# Repetition 916 / 1000
# Repetition 917 / 1000
# Repetition 918 / 1000
# Repetition 919 / 1000
# Repetition 920 / 1000
# Repetition 921 / 1000
# Repetition 922 / 1000
# Repetition 923 / 1000
# Repetition 924 / 1000
# Repetition 925 / 1000
# Repetition 926 / 1000
# Repetition 927 / 1000
# Repetition 928 / 1000
# Repetition 929 / 1000
# Repetition 930 / 1000
# Repetition 931 / 1000
# Repetition 932 / 1000
# Repetition 933 / 1000
# Repetition 934 / 1000
# Repetition 935 / 1000
# Repetition 936 / 1000
# Repetition 937 / 1000
# Repetition 938 / 1000
# Repetition 939 / 1000
# Repetition 940 / 1000
# Repetition 941 / 1000
# Repetition 942 / 1000
# Repetition 943 / 1000
# Repetition 944 / 1000
# Repetition 945 / 1000
# Repetition 946 / 1000
# Repetition 947 / 1000
# Repetition 948 / 1000
# Repetition 949 / 1000
# Repetition 950 / 1000
# Repetition 951 / 1000
# Repetition 952 / 1000
# Repetition 953 / 1000
# Repetition 954 / 1000
# Repetition 955 / 1000
# Repetition 956 / 1000
# Repetition 957 / 1000
# Repetition 958 / 1000
# Repetition 959 / 1000
# Repetition 960 / 1000
# Repetition 961 / 1000
# Repetition 962 / 1000
# Repetition 963 / 1000
# Repetition 964 / 1000
# Repetition 965 / 1000
# Repetition 966 / 1000
# Repetition 967 / 1000
# Repetition 968 / 1000
# Repetition 969 / 1000
# Repetition 970 / 1000
# Repetition 971 / 1000
# Repetition 972 / 1000
# Repetition 973 / 1000
# Repetition 974 / 1000
# Repetition 975 / 1000
# Repetition 976 / 1000
# Repetition 977 / 1000
# Repetition 978 / 1000
# Repetition 979 / 1000
# Repetition 980 / 1000
# Repetition 981 / 1000
# Repetition 982 / 1000
# Repetition 983 / 1000
# Repetition 984 / 1000
# Repetition 985 / 1000
# Repetition 986 / 1000
# Repetition 987 / 1000
# Repetition 988 / 1000
# Repetition 989 / 1000
# Repetition 990 / 1000
# Repetition 991 / 1000
# Repetition 992 / 1000
# Repetition 993 / 1000
# Repetition 994 / 1000
# Repetition 995 / 1000
# Repetition 996 / 1000
# Repetition 997 / 1000
# Repetition 998 / 1000
# Repetition 999 / 1000

# %%
from importlib import reload
errors_fisher = []
errors_local = []
errors_uniform = []
errors_uniform_X = []
decay_test = []
reload(estimator)
for rep, rep_fits in enumerate(fitted_data):
    rep_error_fisher = []
    rep_error_local = []
    rep_error_uniform = []
    rep_error_uniform_X = []

    for decay, (Decay_local, W_local, J_local), (Decay_fisher, W_fisher, J_fisher), (Decay_uni, W_uni, J_uni), (Decay_uni_X, W_uni_X, J_uni_X) in rep_fits:
        fisher_errors = estimator.percent_error(
            np.concatenate([W, [decay], J_list]),
            np.concatenate([W_fisher, Decay_fisher, J_fisher])
        )
        local_errors = estimator.percent_error(
            np.concatenate([W, [decay], J_list]),
            np.concatenate([W_local, Decay_local, J_local])
        )

        uniform_errors = estimator.percent_error(
            np.concatenate([W, [decay], J_list]),
            np.concatenate([W_uni, Decay_uni, J_uni])
        )

        uniform_errors_X = estimator.percent_error(
            np.concatenate([W, [decay], J_list]),
            np.concatenate([W_uni_X, Decay_uni_X, J_uni_X])
        )

        rep_error_fisher.append(fisher_errors)
        rep_error_local.append(local_errors)
        rep_error_uniform.append(uniform_errors)
        rep_error_uniform_X.append(uniform_errors_X)

    errors_fisher.append(rep_error_fisher)
    errors_local.append(rep_error_local)
    errors_uniform.append(rep_error_uniform)
    errors_uniform_X.append(rep_error_uniform_X)

print(np.sqrt(np.mean(decay_test)))
# Out:
# nan
# C:\Users\user\PycharmProjects\ML_Crosstalk\venv\Lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\user\PycharmProjects\ML_Crosstalk\venv\Lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
k = 10

errors_fisher_reshaped = np.array(errors_fisher).transpose()
errors_local_reshaped = np.array(errors_local).transpose()
errors_uniform_reshaped = np.array(errors_uniform).transpose()
errors_fisher_reshaped_X = np.array(errors_uniform_X).transpose()

# errors_local_reshaped = list(map(list, zip(*errors_local)))
# errors_uniform_reshaped = list(map(list, zip(*uniform_local)))
# errors_fisher_reshaped_G = list(map(list, zip(*uniform_local_G)))

errors_fisher_reshaped_a = errors_fisher_reshaped[1]
errors_local_reshaped_a = errors_local_reshaped[1]
errors_uniform_reshaped_a = errors_uniform_reshaped[1]
errors_fisher_reshaped_X_a = errors_fisher_reshaped_X[1]

errors_fisher_reshaped_w = errors_fisher_reshaped[0]
errors_local_reshaped_w = errors_local_reshaped[0]
errors_uniform_reshaped_w = errors_uniform_reshaped[0]
errors_fisher_reshaped_X_w = errors_fisher_reshaped_X[0]


# errors_fisher_median_a, errors_fisher_std_a = np.sqrt(np.mean(errors_fisher_reshaped_a, axis=1)), np.std(errors_fisher_reshaped_a, axis=1)
#
#
errors_fisher_median_a, errors_fisher_std_a = estimator.mean_and_std(errors_fisher_reshaped_a)
errors_local_median_a, errors_local_std_a = estimator.mean_and_std(errors_local_reshaped_a)
errors_uniform_median_a, errors_uniform_std_a = estimator.mean_and_std(errors_uniform_reshaped_a)
errors_uniform_X_median_a, errors_fisher_std_X_a = estimator.mean_and_std(errors_fisher_reshaped_X_a)

errors_fisher_median_w, errors_fisher_std_w = estimator.mean_and_std(errors_fisher_reshaped_w)
errors_local_median_w, errors_local_std_w = estimator.mean_and_std(errors_local_reshaped_w)
errors_uniform_median_w, errors_uniform_std_w = estimator.mean_and_std(errors_uniform_reshaped_w)
errors_uniform_X_median_w, errors_fisher_std_X_w = estimator.mean_and_std(errors_fisher_reshaped_X_w)

# errors_uniform_median_G, errors_uniform_std_G = estimator.mean_of_medians(errors_fisher_reshaped_G, k)
print()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))  # Adjust the figure size to make the plot longer
plt.rcParams['text.usetex'] = True
font = {'family': 'normal',
        'weight': 'bold',
        'size': 14}

plt.rc('font', **font)

plt.errorbar(Decay, np.array(errors_uniform_median_a), yerr= np.array(errors_uniform_std_a),
             fmt='o', color='blue')
plt.errorbar(Decay, np.array(errors_fisher_median_a), yerr= np.array(errors_fisher_std_a),
             fmt='o', color='red')
plt.errorbar(Decay, np.array(errors_local_median_a), yerr= np.array(errors_local_std_a), fmt='o',
             color='green')

plt.errorbar(Decay, np.array(errors_uniform_X_median_a), yerr= np.array(errors_fisher_std_X_a),
             fmt='o', color='black')




plt.title("Dephasing")
# plt.title(f'Shots={Decay} ')
plt.xlabel('$\gamma$')
plt.ylabel('mean / $\gamma$')
plt.grid()
# plt.yscale('log')
# plt.xscale('log')
plt.ylim([0, 0.3])
plt.grid()
plt.legend()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16944\2644166111.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))  # Adjust the figure size to make the plot longer
plt.rcParams['text.usetex'] = True
font = {'family': 'normal',
        'weight': 'bold',
        'size': 14}

plt.rc('font', **font)

plt.errorbar(Decay,  np.array(errors_uniform_median_w), yerr= np.array(errors_uniform_std_w),
             fmt='o', color='blue')
plt.errorbar(Decay,  np.array(errors_fisher_median_w), yerr= np.array(errors_fisher_std_w),
             fmt='o', color='red')
plt.errorbar(Decay,  np.array(errors_local_median_w), yerr= np.array(errors_local_std_w), fmt='o',
             color='green')
plt.errorbar(Decay,  np.array(errors_uniform_X_median_w), yerr= np.array(errors_fisher_std_X_w),
             fmt='o', color='black')
plt.title("Freq")

# plt.title(f'Shots={Decay} ')
plt.xlabel('$\gamma$')
plt.ylabel('mean / $\omega$')
plt.grid()
# plt.yscale('log')
# plt.xscale('log')
# plt.xlim([0, 2])
# plt.ylim([0,50])
plt.grid()

plt.legend()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16944\3305529383.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
index = 6
X = np.array(100 * np.array(np.sqrt(errors_fisher_reshaped_a)))[index][:1000]
# print("Decay: ",Decay[index])
# print(X)
#plot histogram with 10 bins
plt.hist(X, bins=20, color='blue', edgecolor='black', alpha=0.7)
# q75, q25 = np.percentile(X, [75, 25])
# iqr = q75 - q25
print("Decay: ", Decay[index])
print("mean: ", np.mean(X))
print("median: ", np.median(X))
# print("IQR: ", iqr)
# print("std: ", np.std(X))
# Out:
# Decay:  1.501
# mean:  8.510421892888502
# median:  7.198937754804547

# %%
import os
import pandas as pd
user_home = os.path.expanduser("~")

results_df = pd.DataFrame({
    "shots": shots,
    "Decay": Decay,
    "errors_fisher_median_w": errors_fisher_median_w,
    "errors_fisher_std_w": errors_fisher_std_w,
    "errors_local_median_w": errors_local_median_w,
    "errors_local_std_w": errors_local_std_w,
    "errors_uniform_median_w": errors_uniform_median_w,
    "errors_uniform_std_w": errors_uniform_std_w,
    "errors_uniform_X_median_w": errors_uniform_X_median_w,
    "errors_uniform_X_std_w": errors_fisher_std_X_w,
})

# Saving to Excel
results_df.to_excel(user_home + r'\OneDrive - Bar-Ilan University - Students\Data\Crosstalk\graphs_for_paper\stability-Decay_w.xlsx',
    index=False)

results_df = pd.DataFrame({
    "shots": shots,
    "Decay": Decay,
    "errors_fisher_median_a": errors_fisher_median_a,
    "errors_fisher_std_a": errors_fisher_std_a,
    "errors_local_median_a": errors_local_median_a,
    "errors_local_std_a": errors_local_std_a,
    "errors_uniform_median_a": errors_uniform_median_a,
    "errors_uniform_std_a": errors_uniform_std_a,
    "errors_uniform_X_median_a": errors_uniform_X_median_a,
    "errors_uniform_X_std_a": errors_fisher_std_X_a,
})

# Saving to Excel
results_df.to_excel(
    user_home + r'\OneDrive - Bar-Ilan University - Students\Data\Crosstalk\graphs_for_paper\stability-Decay_a.xlsx',
    index=False)

# %%
fisher_a = []
local_a = []
uniform_a = []

fisher_w = []
local_w = []
uniform_w = []

for rep, rep_fits in enumerate(fitted_data):
    # Initialize lists for this repetition
    rep_fisher_a = []
    rep_local_a = []
    rep_uniform_a = []

    rep_fisher_w = []
    rep_local_w = []
    rep_uniform_w = []

    for decay, (Decay_local, W_local, J_local), (Decay_fisher, W_fisher, J_fisher), (Decay_uni, W_uni, J_uni) in rep_fits:
        # Append decays
        rep_fisher_a.append(Decay_fisher)
        rep_local_a.append(Decay_local)
        rep_uniform_a.append(Decay_uni)

        # Append weights
        rep_fisher_w.append(W_fisher)
        rep_local_w.append(W_local)
        rep_uniform_w.append(W_uni)

    # Calculate means for this repetition
    fisher_a.append(rep_fisher_a)
    local_a.append(rep_local_a)
    uniform_a.append(rep_uniform_a)

    fisher_w.append(rep_fisher_w)
    local_w.append(rep_local_w)
    uniform_w.append(rep_uniform_w)



fisher_a = np.array(fisher_a).transpose()[0]
local_a = np.array(local_a).transpose()[0]
uniform_a = np.array(uniform_a).transpose()[0]



fisher_w= np.array(fisher_w).transpose()[0]
local_w = np.array(local_w).transpose()[0]
uniform_w = np.array(uniform_w).transpose()[0]

fisher_a_mean = [np.mean(fisher_a[i]) for i in range(len(Decay))]
fisher_a_std = [np.std(fisher_a[i]) for i in range(len(Decay))]

local_a_mean = [np.mean(local_a[i]) for i in range(len(Decay))]
local_a_std = [np.std(local_a[i])  for i in range(len(Decay))]

uniform_a_mean = [np.mean(uniform_a[i]) for i in range(len(Decay))]
uniform_a_std = [np.std(uniform_a[i])  for i in range(len(Decay))]


fisher_w_mean = [np.mean(fisher_w[i]) for i in range(len(Decay))]
fisher_w_std = [np.std(fisher_w[i])  for i in range(len(Decay))]

local_w_mean = [np.mean(local_w[i]) for i in range(len(Decay))]
local_w_std = [np.std(local_w[i])  for i in range(len(Decay))]

uniform_w_mean = [np.mean(uniform_w[i]) for i in range(len(Decay))]
uniform_w_std = [np.std(uniform_w[i]) for i in range(len(Decay))]





# print("Fisher_a: ", len(fisher_a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 19
#      16 rep_local_w = []
#      17 rep_uniform_w = []
# ---> 19 for decay, (Decay_local, W_local, J_local), (Decay_fisher, W_fisher, J_fisher), (Decay_uni, W_uni, J_uni) in rep_fits:
#      20     # Append decays
#      21     rep_fisher_a.append(Decay_fisher)
#      22     rep_local_a.append(Decay_local)
#
# ValueError: too many values to unpack (expected 4)

# %%
# plt.plot(Decay,decay_fit_t_mean,label='fit')
# plt.scatter(Decay, fisher_a_mean, label='param')
plt.plot(Decay, (np.abs(fisher_a_mean-Decay)))
plt.axline([2, -1], [2, 1], color='black', linestyle='--', label='Stability region')
# plt.errorbar(Decay, Decay/fisher_a_mean, yerr=fisher_a_std, label='param')
plt.ylim([-0.5, 0.5])
plt.xlabel('Dephasing')
plt.ylabel('Absolute difference')
plt.legend()

# %%
import os
import pandas as pd
user_home = os.path.expanduser("~")

results_df = pd.DataFrame({
    "shots": shots,
    "Decay": Decay,
    "fisher_a_mean": fisher_a_mean,
    "fisher_a_std": fisher_a_std,
    "local_a_mean": local_a_mean,
    "local_a_std": local_a_std,
    "uniform_a_mean": uniform_a_mean,
    "uniform_a_std": uniform_a_std,
    "fisher_w_mean": fisher_w_mean,
    "fisher_w_std": fisher_w_std,
    "local_w_mean": local_w_mean,
    "local_w_std": local_w_std,
    "uniform_w_mean": uniform_w_mean,
    "uniform_w_std": uniform_w_std,
})

# Saving to Excel
results_df.to_excel(user_home + r'\OneDrive - Bar-Ilan University - Students\Data\Crosstalk\graphs_for_paper\Unbiased_estimator.xlsx',
    index=False)

# %%
# plt.plot(Decay,omega_fit_t_mean,label='fit')
plt.plot(Decay, [1] * len(Decay))
plt.errorbar(Decay, omega_fit_t_mean, yerr=omega_fit_t_std, label='std')

# %%
from tqdm import tqdm
import random
import numpy as np
T = 1 * np.pi
shots = 1000
errors_fisher = []
errors_local = []
uniform_local = []
uniform_local_G = []
n = 1
delay = [1]
fisher_delay = [0.4439410861020235, 1.784695781691183]

decay_fit = []

repetitions = 100
# W =]
Decay = np.arange(0.001, 4, 0.25)
# np.delete(W, 0)
W = [1]
J = {}
J_list = [random.gauss(1, 0) for _ in range(n - 1)]

for rep in range(repetitions):
    rep_Decay_fisher = []

    rep_decay_fit = []
    for decay in tqdm(Decay, desc=f"Repetition {rep}"):
        # batch_x_det, batch_y_det, batch_x_cross, batch_y_cross = Ramsey_ExperimentV3.ramsey_local(n, shots, delay,
        #                                                                                           [decay],
        #                                                                                           W, J)

        # Decay_local, W_local, J_local = estimator.one_by_one_fit(batch_x_det, batch_y_det, batch_x_cross,
        #                                                          batch_y_cross)

        batch_det_uni_x, batch_cross_uni_x = Ramsey_ExperimentV3.ramsey_local_X(n, shots, uni_delay, [decay], W, J)

        Decay_uni_X, W_uni_X, J_fisher_uni_X = estimator.one_by_one_X(batch_det_uni_x, batch_cross_uni_x)


        # batch_det, batch_cross = Ramsey_ExperimentV3.ramsey_local_X(n, shots, fisher_delay, [decay], W, J)
        # Decay_fisher, W_fisher, J_fisher = estimator.one_by_one_X(batch_det, batch_cross)

        rep_Decay_fisher.append(Decay_uni_X)
    decay_fit.append(rep_Decay_fisher)
# Out:
# Repetition 0: 100%|██████████| 16/16 [00:00<00:00, 54.24it/s]
# Repetition 1: 100%|██████████| 16/16 [00:00<00:00, 52.81it/s]
# Repetition 2: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 3: 100%|██████████| 16/16 [00:00<00:00, 54.61it/s]
# Repetition 4: 100%|██████████| 16/16 [00:00<00:00, 54.05it/s]
# Repetition 5: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 6: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 7: 100%|██████████| 16/16 [00:00<00:00, 53.33it/s]
# Repetition 8: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 9: 100%|██████████| 16/16 [00:00<00:00, 53.16it/s]
# Repetition 10: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 11: 100%|██████████| 16/16 [00:00<00:00, 56.74it/s]
# Repetition 12: 100%|██████████| 16/16 [00:00<00:00, 54.24it/s]
# Repetition 13: 100%|██████████| 16/16 [00:00<00:00, 55.75it/s]
# Repetition 14: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 15: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 16: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 17: 100%|██████████| 16/16 [00:00<00:00, 55.17it/s]
# Repetition 18: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 19: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 20: 100%|██████████| 16/16 [00:00<00:00, 56.94it/s]
# Repetition 21: 100%|██████████| 16/16 [00:00<00:00, 54.61it/s]
# Repetition 22: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 23: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 24: 100%|██████████| 16/16 [00:00<00:00, 56.14it/s]
# Repetition 25: 100%|██████████| 16/16 [00:00<00:00, 53.33it/s]
# Repetition 26: 100%|██████████| 16/16 [00:00<00:00, 53.51it/s]
# Repetition 27: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 28: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 29: 100%|██████████| 16/16 [00:00<00:00, 54.24it/s]
# Repetition 30: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 31: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 32: 100%|██████████| 16/16 [00:00<00:00, 56.14it/s]
# Repetition 33: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 34: 100%|██████████| 16/16 [00:00<00:00, 53.69it/s]
# Repetition 35: 100%|██████████| 16/16 [00:00<00:00, 55.75it/s]
# Repetition 36: 100%|██████████| 16/16 [00:00<00:00, 56.14it/s]
# Repetition 37: 100%|██████████| 16/16 [00:00<00:00, 55.75it/s]
# Repetition 38: 100%|██████████| 16/16 [00:00<00:00, 55.36it/s]
# Repetition 39: 100%|██████████| 16/16 [00:00<00:00, 56.74it/s]
# Repetition 40: 100%|██████████| 16/16 [00:00<00:00, 56.54it/s]
# Repetition 41: 100%|██████████| 16/16 [00:00<00:00, 55.36it/s]
# Repetition 42: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 43: 100%|██████████| 16/16 [00:00<00:00, 57.14it/s]
# Repetition 44: 100%|██████████| 16/16 [00:00<00:00, 55.94it/s]
# Repetition 45: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 46: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 47: 100%|██████████| 16/16 [00:00<00:00, 56.14it/s]
# Repetition 48: 100%|██████████| 16/16 [00:00<00:00, 55.17it/s]
# Repetition 49: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 50: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 51: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 52: 100%|██████████| 16/16 [00:00<00:00, 56.34it/s]
# Repetition 53: 100%|██████████| 16/16 [00:00<00:00, 54.73it/s]
# Repetition 54: 100%|██████████| 16/16 [00:00<00:00, 54.61it/s]
# Repetition 55: 100%|██████████| 16/16 [00:00<00:00, 54.05it/s]
# Repetition 56: 100%|██████████| 16/16 [00:00<00:00, 55.17it/s]
# Repetition 57: 100%|██████████| 16/16 [00:00<00:00, 53.69it/s]
# Repetition 58: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 59: 100%|██████████| 16/16 [00:00<00:00, 55.17it/s]
# Repetition 60: 100%|██████████| 16/16 [00:00<00:00, 54.24it/s]
# Repetition 61: 100%|██████████| 16/16 [00:00<00:00, 55.94it/s]
# Repetition 62: 100%|██████████| 16/16 [00:00<00:00, 55.94it/s]
# Repetition 63: 100%|██████████| 16/16 [00:00<00:00, 54.42it/s]
# Repetition 64: 100%|██████████| 16/16 [00:00<00:00, 56.54it/s]
# Repetition 65: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 66: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 67: 100%|██████████| 16/16 [00:00<00:00, 55.36it/s]
# Repetition 68: 100%|██████████| 16/16 [00:00<00:00, 55.75it/s]
# Repetition 69: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 70: 100%|██████████| 16/16 [00:00<00:00, 53.33it/s]
# Repetition 71: 100%|██████████| 16/16 [00:00<00:00, 53.51it/s]
# Repetition 72: 100%|██████████| 16/16 [00:00<00:00, 53.87it/s]
# Repetition 73: 100%|██████████| 16/16 [00:00<00:00, 55.94it/s]
# Repetition 74: 100%|██████████| 16/16 [00:00<00:00, 54.05it/s]
# Repetition 75: 100%|██████████| 16/16 [00:00<00:00, 52.98it/s]
# Repetition 76: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 77: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 78: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 79: 100%|██████████| 16/16 [00:00<00:00, 52.81it/s]
# Repetition 80: 100%|██████████| 16/16 [00:00<00:00, 54.05it/s]
# Repetition 81: 100%|██████████| 16/16 [00:00<00:00, 55.17it/s]
# Repetition 82: 100%|██████████| 16/16 [00:00<00:00, 53.87it/s]
# Repetition 83: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 84: 100%|██████████| 16/16 [00:00<00:00, 55.94it/s]
# Repetition 85: 100%|██████████| 16/16 [00:00<00:00, 53.16it/s]
# Repetition 86: 100%|██████████| 16/16 [00:00<00:00, 55.56it/s]
# Repetition 87: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 88: 100%|██████████| 16/16 [00:00<00:00, 54.42it/s]
# Repetition 89: 100%|██████████| 16/16 [00:00<00:00, 54.61it/s]
# Repetition 90: 100%|██████████| 16/16 [00:00<00:00, 53.87it/s]
# Repetition 91: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 92: 100%|██████████| 16/16 [00:00<00:00, 53.87it/s]
# Repetition 93: 100%|██████████| 16/16 [00:00<00:00, 53.87it/s]
# Repetition 94: 100%|██████████| 16/16 [00:00<00:00, 53.33it/s]
# Repetition 95: 100%|██████████| 16/16 [00:00<00:00, 56.14it/s]
# Repetition 96: 100%|██████████| 16/16 [00:00<00:00, 54.98it/s]
# Repetition 97: 100%|██████████| 16/16 [00:00<00:00, 54.79it/s]
# Repetition 98: 100%|██████████| 16/16 [00:00<00:00, 53.51it/s]
# Repetition 99: 100%|██████████| 16/16 [00:00<00:00, 55.36it/s]

# %%
import matplotlib.pyplot as plt
decay_fit_t = np.array(decay_fit).transpose()[0]
decay_fit_t_mean = [np.mean(decay_fit_t[i]) for i in range(len(Decay))]
decay_fit_t_std = [np.std(decay_fit_t[i]) / np.sqrt(repetitions) for i in range(len(Decay))]

# plt.plot(Decay,decay_fit_t_mean,label='fit')
plt.plot(Decay, Decay)
plt.errorbar(Decay, decay_fit_t_mean, yerr=decay_fit_t_std, label='std')
plt.legend()

# %%
d = 2
w = 1

batch_det, batch_cross = Ramsey_ExperimentV3.ramsey_local_X(n, shots, fisher_delay, [d], [w], J)
Decay_fisher, W_fisher, J_fisher = estimator.one_by_one_X(batch_det, batch_cross)

x = batch_det.zi
print(x)

f_true = np.sum([np.cos(w*fisher_delay[i]) * np.exp(-d * fisher_delay[i]) - x[i] for i in range(len(fisher_delay))])
f_fit = np.sum([np.cos(W_fisher*fisher_delay[i]) * np.exp(-Decay_fisher * fisher_delay[i]) - x[i] for i in range(len(fisher_delay))])

print("norm true: ", f_true)
print("norm fit: ", f_fit)
